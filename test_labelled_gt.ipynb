# %%
import pickle
import os

# %%
file_path = 'dataset/gt'
file_name= 'all'
data = pickle.load(open(f'{file_path}/{file_name}.pkl', 'rb'))
data
# Out:
# {'walk_stand_0407_0852.csv': {'person': 'engineer',
#   'action': 'walk',
#   'peaks_t': [2.076612903225806,
#    7.903225806451614,
#    14.133064516129036,
#    18.911290322580648,
#    22.258064516129036,
#    25.947580645161295,
#    28.548387096774196,
#    31.841027180004126,
#    34.74425298645574,
#    37.9095755671009,
#    41.43780137355252,
#    44.93141500845222,
#    47.330608556839316,
#    49.97173758909738,
#    52.41125371812964,
#    55.19351178264577,
#    57.874963395548995,
#    60.334640814903835,
#    63.56044726651674,
#    66.32182272927002,
#    68.7411775679797,
#    72.02493236179174,
#    75.06928720050142,
#    77.83138397469497,
#    80.55315816824336,
#    82.55963961970117,
#    85.32173639389472,
#    88.12415574873344,
#    90.40238155518506,
#    93.18463961970119,
#    95.64431703905602,
#    98.30560736163666,
#    100.58311185664803,
#    103.46617637277707,
#    106.64545530037735,
#    108.84303594553865,
#    111.48416497779671,
# ...

# %%
data['walk_stand_0407_0852.csv'].keys()
# Out:
# dict_keys(['person', 'action', 'peaks_t', 'peaks_i', 'file_len'])

# %%
# data['walk_stand_0407_0852.csv']['file_len'] = 3046

# %%
data
# Out:
# {'walk_stand_0407_0852.csv': {'person': 'engineer',
#   'action': 'walk',
#   'peaks_t': [2.076612903225806,
#    7.903225806451614,
#    14.133064516129036,
#    18.911290322580648,
#    22.258064516129036,
#    25.947580645161295,
#    28.548387096774196,
#    31.841027180004126,
#    34.74425298645574,
#    37.9095755671009,
#    41.43780137355252,
#    44.93141500845222,
#    47.330608556839316,
#    49.97173758909738,
#    52.41125371812964,
#    55.19351178264577,
#    57.874963395548995,
#    60.334640814903835,
#    63.56044726651674,
#    66.32182272927002,
#    68.7411775679797,
#    72.02493236179174,
#    75.06928720050142,
#    77.83138397469497,
#    80.55315816824336,
#    82.55963961970117,
#    85.32173639389472,
#    88.12415574873344,
#    90.40238155518506,
#    93.18463961970119,
#    95.64431703905602,
#    98.30560736163666,
#    100.58311185664803,
#    103.46617637277707,
#    106.64545530037735,
#    108.84303594553865,
#    111.48416497779671,
# ...

# %%
# pickle.dump(
#     data,
#     open(f'{file_path}/{file_name}.pkl', 'wb')
# )
